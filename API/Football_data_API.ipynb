# %%
import requests
import json

# %%
API_KEY = '4915aca12c724fa2ae27a0230086ef1d'
ENDPOINT = 'https://api.football-data.org/v2/competitions/' #/v2/competitions/

# %%
headers = {'X-Auth-Token' : API_KEY}
response = requests.get(ENDPOINT, headers = headers, )

# %%
response.json()
# Out:
# {'count': 148,
#  'filters': {},
#  'competitions': [{'id': 2006,
#    'area': {'id': 2001, 'name': 'Africa'},
#    'name': 'WC Qualification',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 7,
#     'startDate': '2015-10-07',
#     'endDate': '2017-11-14',
#     'currentMatchday': 6,
#     'winner': None},
#    'numberOfAvailableSeasons': 1,
#    'lastUpdated': '2018-06-04T23:54:04Z'},
#   {'id': 2025,
#    'area': {'id': 2011, 'name': 'Argentina'},
#    'name': 'Supercopa Argentina',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 430,
#     'startDate': '2019-04-04',
#     'endDate': '2019-04-04',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2018-06-04T23:54:32Z'},
#   {'id': 2023,
#    'area': {'id': 2011, 'name': 'Argentina'},
#    'name': 'Primera B Nacional',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 295,
#     'startDate': '2018-08-25',
#     'endDate': '2019-04-20',
#     'currentMatchday': 25,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-19T11:40:15Z'},
#   {'id': 2024,
#    'area': {'id': 2011, 'name': 'Argentina'},
#    'name': 'Superliga Argentina',
#    'code': 'ASL',
#    'emblemUrl': None,
#    'plan': 'TIER_TWO',
#    'currentSeason': {'id': 282,
#     'startDate': '2018-08-11',
#     'endDate': '2019-04-07',
#     'currentMatchday': 25,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-08T20:15:13Z'},
#   {'id': 2147,
#    'area': {'id': 2014, 'name': 'Asia'},
#    'name': 'WC Qualification',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 458,
#     'startDate': '2015-03-12',
#     'endDate': '2017-10-10',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 1,
#    'lastUpdated': '2019-04-10T11:12:35Z'},
#   {'id': 2026,
#    'area': {'id': 2015, 'name': 'Australia'},
#    'name': 'FFA Cup',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 431,
#     'startDate': '2019-02-14',
#     'endDate': '2019-10-31',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-19T04:35:04Z'},
#   {'id': 2008,
#    'area': {'id': 2015, 'name': 'Australia'},
#    'name': 'A League',
#    'code': 'AAL',
#    'emblemUrl': None,
#    'plan': 'TIER_TWO',
#    'currentSeason': {'id': 283,
#     'startDate': '2018-10-19',
#     'endDate': '2019-04-28',
#     'currentMatchday': 26,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-19T17:15:28Z'},
#   {'id': 2027,
#    'area': {'id': 2016, 'name': 'Austria'},
#    'name': 'ÖFB Cup',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 162,
#     'startDate': '2018-07-20',
#     'endDate': '2019-05-31',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-03T23:29:24Z'},
#   {'id': 2022,
#    'area': {'id': 2016, 'name': 'Austria'},
#    'name': 'Playoffs 1/2',
#    'code': 'APL',
#    'emblemUrl': None,
#    'plan': 'TIER_TWO',
#    'currentSeason': {'id': 24,
#     'startDate': '2018-05-31',
#     'endDate': '2018-06-03',
#     'currentMatchday': None,
#     'winner': {'id': 2022,
#      'name': 'SKN Sankt Pölten',
#      'shortName': 'St. Pölten',
#      'tla': 'STP',
#      'crestUrl': None}},
#    'numberOfAvailableSeasons': 1,
#    'lastUpdated': '2018-08-23T15:47:33Z'},
#   {'id': 2012,
#    'area': {'id': 2016, 'name': 'Austria'},
#    'name': 'Bundesliga',
#    'code': 'ABL',
#    'emblemUrl': None,
#    'plan': 'TIER_THREE',
#    'currentSeason': {'id': 208,
#     'startDate': '2018-07-27',
#     'endDate': '2019-03-17',
#     'currentMatchday': 22,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-19T18:40:15Z'},
#   {'id': 2020,
#    'area': {'id': 2016, 'name': 'Austria'},
#    'name': 'Erste Liga',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 161,
#     'startDate': '2018-07-27',
#     'endDate': '2019-06-01',
#     'currentMatchday': 23,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-19T20:32:29Z'},
#   {'id': 2032,
#    'area': {'id': 2023, 'name': 'Belgium'},
#    'name': 'Playoffs II',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 34,
#     'startDate': '2018-03-31',
#     'endDate': '2018-05-23',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 1,
#    'lastUpdated': '2018-06-02T13:08:02Z'},
#   {'id': 2028,
#    'area': {'id': 2023, 'name': 'Belgium'},
#    'name': 'Coupe de Belgique',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 166,
#     'startDate': '2018-07-29',
#     'endDate': '2019-05-31',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-01-30T23:31:42Z'},
#   {'id': 2009,
#    'area': {'id': 2023, 'name': 'Belgium'},
#    'name': 'Jupiler Pro League',
#    'code': 'BJL',
#    'emblemUrl': None,
#    'plan': 'TIER_TWO',
#    'currentSeason': {'id': 163,
#     'startDate': '2018-07-27',
#     'endDate': '2019-03-17',
#     'currentMatchday': 30,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-19T20:31:49Z'},
#   {'id': 2033,
#    'area': {'id': 2023, 'name': 'Belgium'},
#    'name': 'Division 1B',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 164,
#     'startDate': '2018-08-03',
#     'endDate': '2019-03-01',
#     'currentMatchday': 28,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-19T20:29:48Z'},
#   {'id': 2010,
#    'area': {'id': 2023, 'name': 'Belgium'},
#    'name': 'Supercoupe de Belgique',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 165,
#     'startDate': '2018-07-22',
#     'endDate': '2018-07-22',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2018-06-04T23:58:10Z'},
#   {'id': 2034,
#    'area': {'id': 2028, 'name': 'Bolivia'},
#    'name': 'LFPB',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 427,
#     'startDate': '2019-01-20',
#     'endDate': '2019-12-31',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-19T04:13:48Z'},
#   {'id': 2035,
#    'area': {'id': 2030, 'name': 'Bosnia and Herzegovina'},
#    'name': 'Premier Liga',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 167,
#     'startDate': '2018-07-21',
#     'endDate': '2019-02-09',
#     'currentMatchday': 20,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-14T23:14:32Z'},
#   {'id': 2038,
#    'area': {'id': 2032, 'name': 'Brazil'},
#    'name': 'Série D',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 463,
#     'startDate': '2019-04-05',
#     'endDate': '2019-08-18',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2018-06-04T23:59:34Z'},
#   {'id': 2013,
#    'area': {'id': 2032, 'name': 'Brazil'},
#    'name': 'Série A',
#    'code': 'BSA',
#    'emblemUrl': None,
#    'plan': 'TIER_ONE',
#    'currentSeason': {'id': 460,
#     'startDate': '2019-04-28',
#     'endDate': '2019-12-08',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 3,
#    'lastUpdated': '2018-12-03T22:10:11Z'},
#   {'id': 2036,
#    'area': {'id': 2032, 'name': 'Brazil'},
#    'name': 'Série C',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 462,
#     'startDate': '2019-04-27',
#     'endDate': '2019-10-06',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2018-09-24T02:30:06Z'},
#   {'id': 2037,
#    'area': {'id': 2032, 'name': 'Brazil'},
#    'name': 'Copa do Brasil',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 432,
#     'startDate': '2019-02-06',
#     'endDate': '2019-09-11',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-19T02:43:43Z'},
#   {'id': 2029,
#    'area': {'id': 2032, 'name': 'Brazil'},
#    'name': 'Série B',
#    'code': 'BSB',
#    'emblemUrl': None,
#    'plan': 'TIER_THREE',
#    'currentSeason': {'id': 461,
#     'startDate': '2019-04-26',
#     'endDate': '2019-11-30',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2018-11-25T20:25:17Z'},
#   {'id': 2039,
#    'area': {'id': 2035, 'name': 'Bulgaria'},
#    'name': 'Kupa na Bulgarija',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 419,
#     'startDate': '2018-09-25',
#     'endDate': '2019-05-31',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-17T19:04:24Z'},
#   {'id': 2040,
#    'area': {'id': 2035, 'name': 'Bulgaria'},
#    'name': 'A PFG',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 168,
#     'startDate': '2018-07-20',
#     'endDate': '2019-03-16',
#     'currentMatchday': 26,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-19T20:01:48Z'},
#   {'id': 2041,
#    'area': {'id': 2040, 'name': 'Canada'},
#    'name': 'Canadian Championship',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 433,
#     'startDate': '2019-05-15',
#     'endDate': '2019-09-25',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2018-06-05T00:01:12Z'},
#   {'id': 2043,
#    'area': {'id': 2045, 'name': 'Chile'},
#    'name': 'Supercopa de Chile',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 435,
#     'startDate': '2019-03-23',
#     'endDate': '2019-03-23',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 3,
#    'lastUpdated': '2019-03-24T20:10:07Z'},
#   {'id': 2048,
#    'area': {'id': 2045, 'name': 'Chile'},
#    'name': 'Primera División',
#    'code': 'CPD',
#    'emblemUrl': None,
#    'plan': 'TIER_THREE',
#    'currentSeason': {'id': 434,
#     'startDate': '2019-02-17',
#     'endDate': '2019-12-07',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 3,
#    'lastUpdated': '2019-04-16T20:20:02Z'},
#   {'id': 2042,
#    'area': {'id': 2045, 'name': 'Chile'},
#    'name': 'Playoffs 1/2',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 44,
#     'startDate': '2017-11-25',
#     'endDate': '2017-12-21',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 1,
#    'lastUpdated': '2018-06-05T00:01:23Z'},
#   {'id': 2044,
#    'area': {'id': 2046, 'name': 'China PR'},
#    'name': 'Chinese Super League',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 436,
#     'startDate': '2019-03-01',
#     'endDate': '2019-12-01',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-19T17:05:22Z'},
#   {'id': 2045,
#    'area': {'id': 2049, 'name': 'Colombia'},
#    'name': 'Liga Postobón',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 437,
#     'startDate': '2019-01-27',
#     'endDate': '2019-12-14',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-19T12:20:15Z'},
#   {'id': 2046,
#    'area': {'id': 2049, 'name': 'Colombia'},
#    'name': 'Superliga de Colombia',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 438,
#     'startDate': '2019-01-24',
#     'endDate': '2019-01-27',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2018-06-05T00:02:32Z'},
#   {'id': 2047,
#    'area': {'id': 2058, 'name': 'Croatia'},
#    'name': 'Prva Liga',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 170,
#     'startDate': '2018-07-27',
#     'endDate': '2019-05-25',
#     'currentMatchday': 30,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-19T20:49:30Z'},
#   {'id': 2049,
#    'area': {'id': 2062, 'name': 'Czech Republic'},
#    'name': 'Synot Liga',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 171,
#     'startDate': '2018-07-20',
#     'endDate': '2019-04-27',
#     'currentMatchday': 29,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-16T18:15:02Z'},
#   {'id': 2051,
#    'area': {'id': 2065, 'name': 'Denmark'},
#    'name': 'DBU Pokalen',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 173,
#     'startDate': '2018-08-07',
#     'endDate': '2019-05-31',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-05T04:45:03Z'},
#   {'id': 2141,
#    'area': {'id': 2065, 'name': 'Denmark'},
#    'name': 'Play Offs 1/2',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': None,
#    'numberOfAvailableSeasons': 0,
#    'lastUpdated': '2018-07-13T13:34:22Z'},
#   {'id': 2050,
#    'area': {'id': 2065, 'name': 'Denmark'},
#    'name': 'Superliga',
#    'code': 'DSU',
#    'emblemUrl': None,
#    'plan': 'TIER_THREE',
#    'currentSeason': {'id': 172,
#     'startDate': '2018-07-13',
#     'endDate': '2019-03-17',
#     'currentMatchday': 26,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-19T20:49:48Z'},
#   {'id': 2052,
#    'area': {'id': 2069, 'name': 'Ecuador'},
#    'name': 'Copa Pilsener Serie A',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 439,
#     'startDate': '2019-02-10',
#     'endDate': '2019-12-15',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-16T20:23:23Z'},
#   {'id': 2030,
#    'area': {'id': 2072, 'name': 'England'},
#    'name': 'League One',
#    'code': 'EL1',
#    'emblemUrl': None,
#    'plan': 'TIER_TWO',
#    'currentSeason': {'id': 152,
#     'startDate': '2018-08-04',
#     'endDate': '2019-05-04',
#     'currentMatchday': 43,
#     'winner': None},
#    'numberOfAvailableSeasons': 10,
#    'lastUpdated': '2019-04-19T20:48:10Z'},
#   {'id': 2021,
#    'area': {'id': 2072, 'name': 'England'},
#    'name': 'Premier League',
#    'code': 'PL',
#    'emblemUrl': None,
#    'plan': 'TIER_ONE',
#    'currentSeason': {'id': 151,
#     'startDate': '2018-08-10',
#     'endDate': '2019-05-12',
#     'currentMatchday': 35,
#     'winner': None},
#    'numberOfAvailableSeasons': 26,
#    'lastUpdated': '2019-04-19T10:40:16Z'},
#   {'id': 2056,
#    'area': {'id': 2072, 'name': 'England'},
#    'name': 'FA Community Shield',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 60,
#     'startDate': '2018-08-05',
#     'endDate': '2018-08-05',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2018-06-05T00:05:10Z'},
#   {'id': 2053,
#    'area': {'id': 2072, 'name': 'England'},
#    'name': 'National League',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 174,
#     'startDate': '2018-08-04',
#     'endDate': '2019-04-27',
#     'currentMatchday': 44,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-19T18:38:48Z'},
#   {'id': 2054,
#    'area': {'id': 2072, 'name': 'England'},
#    'name': 'League Two',
#    'code': 'EL2',
#    'emblemUrl': None,
#    'plan': 'TIER_THREE',
#    'currentSeason': {'id': 153,
#     'startDate': '2018-08-04',
#     'endDate': '2019-05-04',
#     'currentMatchday': 43,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-19T18:39:29Z'},
#   {'id': 2139,
#    'area': {'id': 2072, 'name': 'England'},
#    'name': 'Football League Cup',
#    'code': 'FLC',
#    'emblemUrl': None,
#    'plan': 'TIER_THREE',
#    'currentSeason': {'id': 176,
#     'startDate': '2018-08-14',
#     'endDate': '2019-02-24',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-02-24T21:43:52Z'},
#   {'id': 2055,
#    'area': {'id': 2072, 'name': 'England'},
#    'name': 'FA Cup',
#    'code': 'FAC',
#    'emblemUrl': None,
#    'plan': 'TIER_TWO',
#    'currentSeason': {'id': 207,
#     'startDate': '2018-08-10',
#     'endDate': '2019-05-18',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-07T21:45:29Z'},
#   {'id': 2016,
#    'area': {'id': 2072, 'name': 'England'},
#    'name': 'Championship',
#    'code': 'ELC',
#    'emblemUrl': None,
#    'plan': 'TIER_ONE',
#    'currentSeason': {'id': 154,
#     'startDate': '2018-08-03',
#     'endDate': '2019-05-05',
#     'currentMatchday': 43,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-19T20:47:08Z'},
#   {'id': 2057,
#    'area': {'id': 2075, 'name': 'Estonia'},
#    'name': 'Meistriliiga',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 440,
#     'startDate': '2019-03-08',
#     'endDate': '2019-11-09',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-15T01:00:21Z'},
#   {'id': 2007,
#    'area': {'id': 2077, 'name': 'Europe'},
#    'name': 'WC Qualification',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 8,
#     'startDate': '2016-09-04',
#     'endDate': '2017-11-14',
#     'currentMatchday': 10,
#     'winner': None},
#    'numberOfAvailableSeasons': 1,
#    'lastUpdated': '2018-06-05T00:06:41Z'},
#   {'id': 2018,
#    'area': {'id': 2077, 'name': 'Europe'},
#    'name': 'European Championship',
#    'code': 'EC',
#    'emblemUrl': None,
#    'plan': 'TIER_ONE',
#    'currentSeason': {'id': 20,
#     'startDate': '2016-06-10',
#     'endDate': '2016-07-10',
#     'currentMatchday': 3,
#     'winner': {'id': 765,
#      'name': 'Portugal',
#      'shortName': 'Portugal',
#      'tla': 'POR',
#      'crestUrl': 'https://upload.wikimedia.org/wikipedia/commons/5/5c/Flag_of_Portugal.svg'}},
#    'numberOfAvailableSeasons': 1,
#    'lastUpdated': '2018-08-23T12:16:01Z'},
#   {'id': 2058,
#    'area': {'id': 2077, 'name': 'Europe'},
#    'name': "UEFA Women's EURO",
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 62,
#     'startDate': '2017-07-16',
#     'endDate': '2017-08-06',
#     'currentMatchday': 3,
#     'winner': None},
#    'numberOfAvailableSeasons': 1,
#    'lastUpdated': '2018-06-05T00:06:08Z'},
#   {'id': 2001,
#    'area': {'id': 2077, 'name': 'Europe'},
#    'name': 'UEFA Champions League',
#    'code': 'CL',
#    'emblemUrl': 'https://upload.wikimedia.org/wikipedia/en/b/bf/UEFA_Champions_League_logo_2.svg',
#    'plan': 'TIER_ONE',
#    'currentSeason': {'id': 175,
#     'startDate': '2018-06-26',
#     'endDate': '2019-06-01',
#     'currentMatchday': 7,
#     'winner': None},
#    'numberOfAvailableSeasons': 18,
#    'lastUpdated': '2019-04-18T03:00:07Z'},
#   {'id': 2146,
#    'area': {'id': 2077, 'name': 'Europe'},
#    'name': 'UEFA Europa League',
#    'code': 'EL',
#    'emblemUrl': None,
#    'plan': 'TIER_TWO',
#    'currentSeason': {'id': 293,
#     'startDate': '2018-06-26',
#     'endDate': '2019-05-29',
#     'currentMatchday': 7,
#     'winner': None},
#    'numberOfAvailableSeasons': 1,
#    'lastUpdated': '2019-04-19T00:30:04Z'},
#   {'id': 2031,
#    'area': {'id': 2080, 'name': 'Finland'},
#    'name': 'Veikkausliiga',
#    'code': 'VEI',
#    'emblemUrl': None,
#    'plan': 'TIER_THREE',
#    'currentSeason': {'id': 441,
#     'startDate': '2019-04-01',
#     'endDate': '2019-10-31',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-19T19:43:28Z'},
#   {'id': 2059,
#    'area': {'id': 2080, 'name': 'Finland'},
#    'name': 'Suomen Cup',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 442,
#     'startDate': '2019-01-18',
#     'endDate': '2019-08-31',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-03-31T19:36:45Z'},
#   {'id': 2143,
#    'area': {'id': 2081, 'name': 'France'},
#    'name': 'Playoffs 1/2',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 211,
#     'startDate': '2018-05-23',
#     'endDate': '2018-05-27',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 1,
#    'lastUpdated': '2018-07-12T14:32:17Z'},
#   {'id': 2142,
#    'area': {'id': 2081, 'name': 'France'},
#    'name': 'Ligue 2',
#    'code': 'FL2',
#    'emblemUrl': None,
#    'plan': 'TIER_TWO',
#    'currentSeason': {'id': 210,
#     'startDate': '2018-07-27',
#     'endDate': '2019-05-17',
#     'currentMatchday': 33,
#     'winner': None},
#    'numberOfAvailableSeasons': 21,
#    'lastUpdated': '2019-04-19T20:49:30Z'},
#   {'id': 2144,
#    'area': {'id': 2081, 'name': 'France'},
#    'name': 'Playoffs 2/3',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 212,
#     'startDate': '2018-05-22',
#     'endDate': '2018-05-27',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 1,
#    'lastUpdated': '2018-09-25T15:07:37Z'},
#   {'id': 2138,
#    'area': {'id': 2081, 'name': 'France'},
#    'name': 'Coupe de France',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 418,
#     'startDate': '2018-11-17',
#     'endDate': '2019-04-27',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-04T08:50:06Z'},
#   {'id': 2015,
#    'area': {'id': 2081, 'name': 'France'},
#    'name': 'Ligue 1',
#    'code': 'FL1',
#    'emblemUrl': None,
#    'plan': 'TIER_ONE',
#    'currentSeason': {'id': 177,
#     'startDate': '2018-08-10',
#     'endDate': '2019-05-25',
#     'currentMatchday': 33,
#     'winner': None},
#    'numberOfAvailableSeasons': 8,
#    'lastUpdated': '2019-04-19T20:45:23Z'},
#   {'id': 2135,
#    'area': {'id': 2081, 'name': 'France'},
#    'name': 'Coupe de la Ligue',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 284,
#     'startDate': '2018-08-14',
#     'endDate': '2019-03-30',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-03-31T08:15:18Z'},
#   {'id': 2136,
#    'area': {'id': 2081, 'name': 'France'},
#    'name': 'Trophée des Champions',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 206,
#     'startDate': '2018-08-04',
#     'endDate': '2018-08-04',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2018-06-05T00:08:21Z'},
#   {'id': 2133,
#    'area': {'id': 2088, 'name': 'Germany'},
#    'name': 'Frauen Bundesliga',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 142,
#     'startDate': '2017-09-02',
#     'endDate': '2018-06-03',
#     'currentMatchday': 22,
#     'winner': {'id': 7522,
#      'name': 'VfL Wolfsburg',
#      'shortName': None,
#      'tla': None,
#      'crestUrl': None}},
#    'numberOfAvailableSeasons': 1,
#    'lastUpdated': '2018-06-05T00:09:39Z'},
#   {'id': 2011,
#    'area': {'id': 2088, 'name': 'Germany'},
#    'name': 'DFB-Pokal',
#    'code': 'DFB',
#    'emblemUrl': None,
#    'plan': 'TIER_TWO',
#    'currentSeason': {'id': 12,
#     'startDate': '2018-08-17',
#     'endDate': '2019-05-25',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-03T23:46:40Z'},
#   {'id': 2004,
#    'area': {'id': 2088, 'name': 'Germany'},
#    'name': '2. Bundesliga',
#    'code': 'BL2',
#    'emblemUrl': None,
#    'plan': 'TIER_TWO',
#    'currentSeason': {'id': 157,
#     'startDate': '2018-08-03',
#     'endDate': '2019-05-19',
#     'currentMatchday': 30,
#     'winner': None},
#    'numberOfAvailableSeasons': 23,
#    'lastUpdated': '2019-04-19T18:50:17Z'},
#   {'id': 2134,
#    'area': {'id': 2088, 'name': 'Germany'},
#    'name': 'DFL Super Cup',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 158,
#     'startDate': '2018-08-12',
#     'endDate': '2018-08-12',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2018-06-05T00:10:19Z'},
#   {'id': 2129,
#    'area': {'id': 2088, 'name': 'Germany'},
#    'name': 'Regionalliga',
#    'code': 'REG',
#    'emblemUrl': None,
#    'plan': 'TIER_THREE',
#    'currentSeason': {'id': 178,
#     'startDate': '2018-07-12',
#     'endDate': '2019-05-18',
#     'currentMatchday': 30,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-19T03:35:03Z'},
#   {'id': 2140,
#    'area': {'id': 2088, 'name': 'Germany'},
#    'name': '3. Liga',
#    'code': 'BL3',
#    'emblemUrl': None,
#    'plan': 'TIER_THREE',
#    'currentSeason': {'id': 150,
#     'startDate': '2018-07-27',
#     'endDate': '2019-05-18',
#     'currentMatchday': 34,
#     'winner': None},
#    'numberOfAvailableSeasons': 7,
#    'lastUpdated': '2019-04-16T18:15:02Z'},
#   {'id': 2002,
#    'area': {'id': 2088, 'name': 'Germany'},
#    'name': 'Bundesliga',
#    'code': 'BL1',
#    'emblemUrl': None,
#    'plan': 'TIER_ONE',
#    'currentSeason': {'id': 155,
#     'startDate': '2018-08-24',
#     'endDate': '2019-05-18',
#     'currentMatchday': 30,
#     'winner': None},
#    'numberOfAvailableSeasons': 23,
#    'lastUpdated': '2019-04-19T19:05:17Z'},
#   {'id': 2131,
#    'area': {'id': 2093, 'name': 'Greece'},
#    'name': 'Greek Cup',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 420,
#     'startDate': '2018-08-26',
#     'endDate': '2019-08-26',
#     'currentMatchday': 3,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-04T23:10:06Z'},
#   {'id': 2132,
#    'area': {'id': 2093, 'name': 'Greece'},
#    'name': 'Super League',
#    'code': 'GSL',
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 299,
#     'startDate': '2018-08-25',
#     'endDate': '2019-05-05',
#     'currentMatchday': 29,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-15T19:40:12Z'},
#   {'id': 2130,
#    'area': {'id': 2106, 'name': 'Hungary'},
#    'name': 'Magyar Kupa',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 297,
#     'startDate': '2019-09-22',
#     'endDate': '2019-05-01',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-17T19:04:24Z'},
#   {'id': 2128,
#    'area': {'id': 2106, 'name': 'Hungary'},
#    'name': 'NB I',
#    'code': 'HNB',
#    'emblemUrl': None,
#    'plan': 'TIER_THREE',
#    'currentSeason': {'id': 179,
#     'startDate': '2018-07-21',
#     'endDate': '2019-05-19',
#     'currentMatchday': 29,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-13T20:32:19Z'},
#   {'id': 2127,
#    'area': {'id': 2107, 'name': 'Iceland'},
#    'name': 'Úrvalsdeild',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 443,
#     'startDate': '2019-04-26',
#     'endDate': '2019-09-28',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2018-09-30T07:05:12Z'},
#   {'id': 2126,
#    'area': {'id': 2108, 'name': 'India'},
#    'name': 'I-League',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 421,
#     'startDate': '2018-10-26',
#     'endDate': '2019-03-03',
#     'currentMatchday': 21,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-03-09T17:47:37Z'},
#   {'id': 2125,
#    'area': {'id': 2113, 'name': 'Israel'},
#    'name': "Ligat ha'Al",
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 205,
#     'startDate': '2018-08-25',
#     'endDate': '2019-05-25',
#     'currentMatchday': 26,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-16T17:50:02Z'},
#   {'id': 2122,
#    'area': {'id': 2114, 'name': 'Italy'},
#    'name': 'Coppa Italia',
#    'code': 'CIT',
#    'emblemUrl': None,
#    'plan': 'TIER_THREE',
#    'currentSeason': {'id': 285,
#     'startDate': '2018-07-28',
#     'endDate': '2019-05-15',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-02-27T22:57:57Z'},
#   {'id': 2123,
#    'area': {'id': 2114, 'name': 'Italy'},
#    'name': 'Serie C',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 298,
#     'startDate': '2018-09-16',
#     'endDate': '2019-05-05',
#     'currentMatchday': 36,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-18T22:25:12Z'},
#   {'id': 2124,
#    'area': {'id': 2114, 'name': 'Italy'},
#    'name': 'Supercoppa',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 159,
#     'startDate': '2019-01-12',
#     'endDate': '2019-01-12',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-01-17T08:15:01Z'},
#   {'id': 2019,
#    'area': {'id': 2114, 'name': 'Italy'},
#    'name': 'Serie A',
#    'code': 'SA',
#    'emblemUrl': None,
#    'plan': 'TIER_ONE',
#    'currentSeason': {'id': 290,
#     'startDate': '2018-08-18',
#     'endDate': '2019-05-26',
#     'currentMatchday': 33,
#     'winner': None},
#    'numberOfAvailableSeasons': 14,
#    'lastUpdated': '2019-04-19T18:40:15Z'},
#   {'id': 2121,
#    'area': {'id': 2114, 'name': 'Italy'},
#    'name': 'Serie B',
#    'code': 'SB',
#    'emblemUrl': None,
#    'plan': 'TIER_TWO',
#    'currentSeason': {'id': 294,
#     'startDate': '2018-08-24',
#     'endDate': '2019-05-11',
#     'currentMatchday': 34,
#     'winner': None},
#    'numberOfAvailableSeasons': 14,
#    'lastUpdated': '2019-04-16T21:20:02Z'},
#   {'id': 2118,
#    'area': {'id': 2116, 'name': 'Japan'},
#    'name': 'J.League Cup',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 446,
#     'startDate': '2019-03-06',
#     'endDate': '2019-10-26',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-11T23:40:04Z'},
#   {'id': 2119,
#    'area': {'id': 2116, 'name': 'Japan'},
#    'name': 'J. League',
#    'code': 'JJL',
#    'emblemUrl': None,
#    'plan': 'TIER_TWO',
#    'currentSeason': {'id': 444,
#     'startDate': '2019-02-22',
#     'endDate': '2019-12-07',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-19T16:51:28Z'},
#   {'id': 2120,
#    'area': {'id': 2116, 'name': 'Japan'},
#    'name': 'Super Cup',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 447,
#     'startDate': '2019-02-16',
#     'endDate': '2019-02-16',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2018-06-05T00:15:43Z'},
#   {'id': 2117,
#    'area': {'id': 2116, 'name': 'Japan'},
#    'name': 'J. League Division 2',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 445,
#     'startDate': '2019-02-24',
#     'endDate': '2019-11-24',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-14T13:13:12Z'},
#   {'id': 2116,
#    'area': {'id': 2129, 'name': 'Latvia'},
#    'name': 'Virslīga',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 448,
#     'startDate': '2019-03-09',
#     'endDate': '2019-11-09',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-19T19:03:09Z'},
#   {'id': 2115,
#    'area': {'id': 2135, 'name': 'Lithuania'},
#    'name': 'A Lyga',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 124,
#     'startDate': '2018-02-24',
#     'endDate': '2018-10-30',
#     'currentMatchday': 2,
#     'winner': None},
#    'numberOfAvailableSeasons': 1,
#    'lastUpdated': '2018-11-12T13:20:09Z'},
#   {'id': 2114,
#    'area': {'id': 2143, 'name': 'Malta'},
#    'name': 'Premier League',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 160,
#     'startDate': '2018-08-17',
#     'endDate': '2019-04-25',
#     'currentMatchday': 25,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-16T18:15:02Z'},
#   {'id': 2111,
#    'area': {'id': 2149, 'name': 'Mexico'},
#    'name': 'Copa MX',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 187,
#     'startDate': '2018-07-25',
#     'endDate': '2019-05-31',
#     'currentMatchday': 6,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-12T21:15:01Z'},
#   {'id': 2112,
#    'area': {'id': 2149, 'name': 'Mexico'},
#    'name': 'SuperCopa MX',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 121,
#     'startDate': '2018-07-15',
#     'endDate': '2018-07-15',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2018-06-05T00:17:16Z'},
#   {'id': 2113,
#    'area': {'id': 2149, 'name': 'Mexico'},
#    'name': 'Liga MX',
#    'code': 'LMX',
#    'emblemUrl': None,
#    'plan': 'TIER_THREE',
#    'currentSeason': {'id': 186,
#     'startDate': '2018-07-21',
#     'endDate': '2018-11-25',
#     'currentMatchday': 17,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-19T13:00:18Z'},
#   {'id': 2003,
#    'area': {'id': 2163, 'name': 'Netherlands'},
#    'name': 'Eredivisie',
#    'code': 'DED',
#    'emblemUrl': None,
#    'plan': 'TIER_ONE',
#    'currentSeason': {'id': 156,
#     'startDate': '2018-08-10',
#     'endDate': '2019-05-12',
#     'currentMatchday': 31,
#     'winner': None},
#    'numberOfAvailableSeasons': 9,
#    'lastUpdated': '2019-04-19T20:00:26Z'},
#   {'id': 2005,
#    'area': {'id': 2163, 'name': 'Netherlands'},
#    'name': 'Jupiler League',
#    'code': 'DJL',
#    'emblemUrl': None,
#    'plan': 'TIER_THREE',
#    'currentSeason': {'id': 180,
#     'startDate': '2018-08-17',
#     'endDate': '2019-05-03',
#     'currentMatchday': 35,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-19T20:49:48Z'},
#   {'id': 2109,
#    'area': {'id': 2163, 'name': 'Netherlands'},
#    'name': 'KNVB Beker',
#    'code': 'KNV',
#    'emblemUrl': None,
#    'plan': 'TIER_THREE',
#    'currentSeason': {'id': 181,
#     'startDate': '2018-08-18',
#     'endDate': '2018-08-25',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-03-01T00:40:01Z'},
#   {'id': 2110,
#    'area': {'id': 2163, 'name': 'Netherlands'},
#    'name': 'Johan Cruijff Schaal',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 182,
#     'startDate': '2018-08-04',
#     'endDate': '2018-08-04',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2018-06-05T00:18:23Z'},
#   {'id': 2107,
#    'area': {'id': 2171, 'name': 'Northern Ireland'},
#    'name': 'Premiership',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 204,
#     'startDate': '2018-08-04',
#     'endDate': '2019-03-23',
#     'currentMatchday': 33,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-19T20:47:28Z'},
#   {'id': 2108,
#    'area': {'id': 2171, 'name': 'Northern Ireland'},
#    'name': 'League Cup',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 203,
#     'startDate': '2018-08-04',
#     'endDate': '2019-02-16',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-02-16T21:39:28Z'},
#   {'id': 2104,
#    'area': {'id': 2173, 'name': 'Norway'},
#    'name': 'Playoffs 1/2',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 112,
#     'startDate': '2017-11-29',
#     'endDate': '2017-12-02',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 1,
#    'lastUpdated': '2018-06-05T00:20:23Z'},
#   {'id': 2105,
#    'area': {'id': 2173, 'name': 'Norway'},
#    'name': '1. divisjon',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 450,
#     'startDate': '2019-03-30',
#     'endDate': '2019-11-27',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-15T20:40:15Z'},
#   {'id': 2106,
#    'area': {'id': 2173, 'name': 'Norway'},
#    'name': 'Tippeligaen',
#    'code': 'TIP',
#    'emblemUrl': None,
#    'plan': 'TIER_THREE',
#    'currentSeason': {'id': 449,
#     'startDate': '2019-03-30',
#     'endDate': '2019-11-30',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-15T20:40:15Z'},
#   {'id': 2103,
#    'area': {'id': 2175, 'name': 'Oceania'},
#    'name': 'WC Qualification',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 111,
#     'startDate': '2015-08-31',
#     'endDate': '2017-09-05',
#     'currentMatchday': 6,
#     'winner': None},
#    'numberOfAvailableSeasons': 1,
#    'lastUpdated': '2018-06-05T00:20:43Z'},
#   {'id': 2102,
#    'area': {'id': 2181, 'name': 'Panama'},
#    'name': 'Liga Panameña de Fútbol',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 422,
#     'startDate': '2018-07-28',
#     'endDate': '2019-05-31',
#     'currentMatchday': 18,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-18T15:25:11Z'},
#   {'id': 2101,
#    'area': {'id': 2184, 'name': 'Peru'},
#    'name': 'Primera División',
#    'code': 'PPD',
#    'emblemUrl': None,
#    'plan': 'TIER_THREE',
#    'currentSeason': {'id': 451,
#     'startDate': '2019-02-17',
#     'endDate': '2019-11-24',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-18T19:15:11Z'},
#   {'id': 2100,
#    'area': {'id': 2186, 'name': 'Poland'},
#    'name': 'Puchar Polski',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 198,
#     'startDate': '2018-08-07',
#     'endDate': '2019-05-02',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-11T20:00:05Z'},
#   {'id': 2099,
#    'area': {'id': 2186, 'name': 'Poland'},
#    'name': 'Superpuchar Polski',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 107,
#     'startDate': '2018-07-14',
#     'endDate': '2018-07-14',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2018-06-05T00:21:44Z'},
#   {'id': 2017,
#    'area': {'id': 2187, 'name': 'Portugal'},
#    'name': 'Primeira Liga',
#    'code': 'PPL',
#    'emblemUrl': None,
#    'plan': 'TIER_ONE',
#    'currentSeason': {'id': 183,
#     'startDate': '2018-08-10',
#     'endDate': '2019-05-19',
#     'currentMatchday': 30,
#     'winner': None},
#    'numberOfAvailableSeasons': 8,
#    'lastUpdated': '2019-04-19T20:48:48Z'},
#   {'id': 2096,
#    'area': {'id': 2187, 'name': 'Portugal'},
#    'name': 'Liga2 Cabovisão',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 184,
#     'startDate': '2018-08-11',
#     'endDate': '2019-05-19',
#     'currentMatchday': 30,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-19T19:50:48Z'},
#   {'id': 2097,
#    'area': {'id': 2187, 'name': 'Portugal'},
#    'name': 'Supertaça Cândido de Oliveira',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 104,
#     'startDate': '2018-08-04',
#     'endDate': '2018-08-04',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2018-06-05T00:22:37Z'},
#   {'id': 2098,
#    'area': {'id': 2187, 'name': 'Portugal'},
#    'name': 'Taça de Portugal',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 425,
#     'startDate': '2018-09-09',
#     'endDate': '2019-05-26',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-03T22:55:40Z'},
#   {'id': 2095,
#    'area': {'id': 2192, 'name': 'Republic of Ireland'},
#    'name': 'Premier Division',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 424,
#     'startDate': '2019-02-15',
#     'endDate': '2019-10-27',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-19T20:47:28Z'},
#   {'id': 2092,
#    'area': {'id': 2194, 'name': 'Romania'},
#    'name': 'Liga II',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 423,
#     'startDate': '2018-07-21',
#     'endDate': '2019-05-31',
#     'currentMatchday': 31,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-19T13:40:17Z'},
#   {'id': 2093,
#    'area': {'id': 2194, 'name': 'Romania'},
#    'name': 'Supercupa României',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 202,
#     'startDate': '2018-07-14',
#     'endDate': '2018-07-14',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2018-06-05T00:23:54Z'},
#   {'id': 2094,
#    'area': {'id': 2194, 'name': 'Romania'},
#    'name': 'Liga I',
#    'code': 'RL1',
#    'emblemUrl': None,
#    'plan': 'TIER_THREE',
#    'currentSeason': {'id': 185,
#     'startDate': '2018-07-20',
#     'endDate': '2019-03-02',
#     'currentMatchday': 26,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-19T20:06:10Z'},
#   {'id': 2089,
#    'area': {'id': 2195, 'name': 'Russia'},
#    'name': 'Russian Cup',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 287,
#     'startDate': '2018-07-21',
#     'endDate': '2019-05-31',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-04T22:55:07Z'},
#   {'id': 2137,
#    'area': {'id': 2195, 'name': 'Russia'},
#    'name': 'RFPL',
#    'code': 'RFPL',
#    'emblemUrl': None,
#    'plan': 'TIER_TWO',
#    'currentSeason': {'id': 201,
#     'startDate': '2018-07-28',
#     'endDate': '2019-05-26',
#     'currentMatchday': 24,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-19T20:49:30Z'},
#   {'id': 2090,
#    'area': {'id': 2195, 'name': 'Russia'},
#    'name': 'Playoffs 1/2',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 96,
#     'startDate': '2018-05-17',
#     'endDate': '2018-05-20',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 1,
#    'lastUpdated': '2018-06-05T00:24:32Z'},
#   {'id': 2091,
#    'area': {'id': 2195, 'name': 'Russia'},
#    'name': 'Russian Super Cup',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 199,
#     'startDate': '2018-07-27',
#     'endDate': '2018-07-27',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2018-06-05T00:24:42Z'},
#   {'id': 2088,
#    'area': {'id': 2195, 'name': 'Russia'},
#    'name': 'FNL',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 200,
#     'startDate': '2018-07-17',
#     'endDate': '2019-05-25',
#     'currentMatchday': 32,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-19T19:05:23Z'},
#   {'id': 2085,
#    'area': {'id': 2204, 'name': 'Scotland'},
#    'name': 'Championship',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 197,
#     'startDate': '2018-08-04',
#     'endDate': '2019-05-04',
#     'currentMatchday': 34,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-19T20:05:23Z'},
#   {'id': 2086,
#    'area': {'id': 2204, 'name': 'Scotland'},
#    'name': 'Playoffs 2/3',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 92,
#     'startDate': '2018-05-02',
#     'endDate': '2018-05-13',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 1,
#    'lastUpdated': '2018-06-05T00:25:54Z'},
#   {'id': 2087,
#    'area': {'id': 2204, 'name': 'Scotland'},
#    'name': 'Scottish Cup',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 288,
#     'startDate': '2018-08-11',
#     'endDate': '2019-05-31',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-14T21:16:53Z'},
#   {'id': 2084,
#    'area': {'id': 2204, 'name': 'Scotland'},
#    'name': 'Premier League',
#    'code': 'SPL',
#    'emblemUrl': None,
#    'plan': 'TIER_TWO',
#    'currentSeason': {'id': 196,
#     'startDate': '2018-08-04',
#     'endDate': '2019-04-06',
#     'currentMatchday': 33,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-07T18:13:00Z'},
#   {'id': 2083,
#    'area': {'id': 2219, 'name': 'South Africa'},
#    'name': 'ABSA Premiership',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 289,
#     'startDate': '2018-08-04',
#     'endDate': '2019-08-11',
#     'currentMatchday': 26,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-18T03:50:02Z'},
#   {'id': 2081,
#    'area': {'id': 2220, 'name': 'South America'},
#    'name': 'Copa Sudamericana',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 428,
#     'startDate': '2019-02-06',
#     'endDate': '2019-11-09',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-19T11:42:08Z'},
#   {'id': 2082,
#    'area': {'id': 2220, 'name': 'South America'},
#    'name': 'WC Qualification',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 88,
#     'startDate': '2015-10-08',
#     'endDate': '2017-10-11',
#     'currentMatchday': 18,
#     'winner': None},
#    'numberOfAvailableSeasons': 1,
#    'lastUpdated': '2018-06-05T00:27:01Z'},
#   {'id': 2080,
#    'area': {'id': 2220, 'name': 'South America'},
#    'name': 'Copa America',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 452,
#     'startDate': '2019-06-14',
#     'endDate': '2019-07-07',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2018-06-05T00:26:43Z'},
#   {'id': 2014,
#    'area': {'id': 2224, 'name': 'Spain'},
#    'name': 'Primera Division',
#    'code': 'PD',
#    'emblemUrl': None,
#    'plan': 'TIER_ONE',
#    'currentSeason': {'id': 281,
#     'startDate': '2018-08-17',
#     'endDate': '2019-05-26',
#     'currentMatchday': 33,
#     'winner': None},
#    'numberOfAvailableSeasons': 26,
#    'lastUpdated': '2019-04-19T20:48:48Z'},
#   {'id': 2078,
#    'area': {'id': 2224, 'name': 'Spain'},
#    'name': 'Supercopa de España',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 83,
#     'startDate': '2018-08-12',
#     'endDate': '2018-08-14',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2018-06-05T00:27:12Z'},
#   {'id': 2079,
#    'area': {'id': 2224, 'name': 'Spain'},
#    'name': 'Copa del Rey',
#    'code': 'CDR',
#    'emblemUrl': None,
#    'plan': 'TIER_THREE',
#    'currentSeason': {'id': 291,
#     'startDate': '2018-09-05',
#     'endDate': '2019-03-30',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-02-28T23:39:16Z'},
#   {'id': 2077,
#    'area': {'id': 2224, 'name': 'Spain'},
#    'name': 'Segunda División',
#    'code': 'SD',
#    'emblemUrl': None,
#    'plan': 'TIER_TWO',
#    'currentSeason': {'id': 286,
#     'startDate': '2018-08-17',
#     'endDate': '2019-06-09',
#     'currentMatchday': 35,
#     'winner': None},
#    'numberOfAvailableSeasons': 7,
#    'lastUpdated': '2019-04-19T20:49:08Z'},
#   {'id': 2074,
#    'area': {'id': 2233, 'name': 'Sweden'},
#    'name': 'Superettan',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 454,
#     'startDate': '2019-03-31',
#     'endDate': '2019-11-02',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-19T19:49:28Z'},
#   {'id': 2075,
#    'area': {'id': 2233, 'name': 'Sweden'},
#    'name': 'Playoffs 2/3',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 79,
#     'startDate': '2017-11-08',
#     'endDate': '2017-11-11',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 1,
#    'lastUpdated': '2018-06-05T00:28:43Z'},
#   {'id': 2076,
#    'area': {'id': 2233, 'name': 'Sweden'},
#    'name': 'Playoffs 1/2',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 80,
#     'startDate': '2017-11-15',
#     'endDate': '2017-11-19',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 1,
#    'lastUpdated': '2018-06-05T00:28:54Z'},
#   {'id': 2073,
#    'area': {'id': 2233, 'name': 'Sweden'},
#    'name': 'Allsvenskan',
#    'code': 'ALL',
#    'emblemUrl': None,
#    'plan': 'TIER_THREE',
#    'currentSeason': {'id': 453,
#     'startDate': '2019-03-31',
#     'endDate': '2019-11-02',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-19T18:59:28Z'},
#   {'id': 2071,
#    'area': {'id': 2234, 'name': 'Switzerland'},
#    'name': 'Schweizer Pokal',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 194,
#     'startDate': '2018-08-18',
#     'endDate': '2019-05-31',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-03-06T19:48:16Z'},
#   {'id': 2072,
#    'area': {'id': 2234, 'name': 'Switzerland'},
#    'name': 'Super League',
#    'code': 'SSL',
#    'emblemUrl': None,
#    'plan': 'TIER_THREE',
#    'currentSeason': {'id': 195,
#     'startDate': '2018-07-21',
#     'endDate': '2019-05-25',
#     'currentMatchday': 30,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-19T20:01:09Z'},
#   {'id': 2070,
#    'area': {'id': 2247, 'name': 'Turkey'},
#    'name': 'Süper Lig',
#    'code': 'TSL',
#    'emblemUrl': None,
#    'plan': 'TIER_THREE',
#    'currentSeason': {'id': 192,
#     'startDate': '2018-08-10',
#     'endDate': '2019-05-26',
#     'currentMatchday': 29,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-19T20:39:09Z'},
#   {'id': 2068,
#    'area': {'id': 2247, 'name': 'Turkey'},
#    'name': '1. Lig',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 193,
#     'startDate': '2018-08-10',
#     'endDate': '2019-05-18',
#     'currentMatchday': 30,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-19T20:39:28Z'},
#   {'id': 2069,
#    'area': {'id': 2247, 'name': 'Turkey'},
#    'name': 'TFF Süper Kupa',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 426,
#     'startDate': '2018-08-05',
#     'endDate': '2018-08-05',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2018-06-05T00:30:33Z'},
#   {'id': 2066,
#    'area': {'id': 2253, 'name': 'Ukraine'},
#    'name': 'Playoffs 1/2',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 70,
#     'startDate': '2018-05-23',
#     'endDate': '2018-05-27',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 1,
#    'lastUpdated': '2018-06-02T14:03:07Z'},
#   {'id': 2064,
#    'area': {'id': 2253, 'name': 'Ukraine'},
#    'name': 'Premier Liha',
#    'code': 'UPL',
#    'emblemUrl': None,
#    'plan': 'TIER_THREE',
#    'currentSeason': {'id': 189,
#     'startDate': '2018-07-22',
#     'endDate': '2018-10-06',
#     'currentMatchday': 11,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-15T20:40:15Z'},
#   {'id': 2067,
#    'area': {'id': 2253, 'name': 'Ukraine'},
#    'name': 'Superkubok Ukrainy',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 191,
#     'startDate': '2018-07-21',
#     'endDate': '2018-07-21',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2018-06-05T00:30:59Z'},
#   {'id': 2065,
#    'area': {'id': 2253, 'name': 'Ukraine'},
#    'name': 'Kubok Ukrainy',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 190,
#     'startDate': '2018-07-17',
#     'endDate': '2019-05-15',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-17T18:38:05Z'},
#   {'id': 2145,
#    'area': {'id': 2256, 'name': 'United States'},
#    'name': 'MLS',
#    'code': 'MLS',
#    'emblemUrl': None,
#    'plan': 'TIER_TWO',
#    'currentSeason': {'id': 429,
#     'startDate': '2019-03-02',
#     'endDate': '2019-11-10',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-19T00:00:37Z'},
#   {'id': 2063,
#    'area': {'id': 2257, 'name': 'Uruguay'},
#    'name': 'Primera División',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 455,
#     'startDate': '2019-02-16',
#     'endDate': '2019-11-30',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-15T04:17:44Z'},
#   {'id': 2062,
#    'area': {'id': 2262, 'name': 'Venezuela'},
#    'name': 'Primera División',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 456,
#     'startDate': '2019-01-25',
#     'endDate': '2019-12-07',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-19T00:15:04Z'},
#   {'id': 2061,
#    'area': {'id': 2263, 'name': 'Vietnam'},
#    'name': 'V-League',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 457,
#     'startDate': '2019-02-23',
#     'endDate': '2019-12-07',
#     'currentMatchday': None,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-19T13:04:08Z'},
#   {'id': 2060,
#    'area': {'id': 2264, 'name': 'Wales'},
#    'name': 'Welsh Premier League',
#    'code': None,
#    'emblemUrl': None,
#    'plan': 'TIER_FOUR',
#    'currentSeason': {'id': 188,
#     'startDate': '2018-08-10',
#     'endDate': '2019-01-12',
#     'currentMatchday': 22,
#     'winner': None},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2019-04-19T16:33:49Z'},
#   {'id': 2000,
#    'area': {'id': 2267, 'name': 'World'},
#    'name': 'FIFA World Cup',
#    'code': 'WC',
#    'emblemUrl': None,
#    'plan': 'TIER_ONE',
#    'currentSeason': {'id': 1,
#     'startDate': '2018-06-14',
#     'endDate': '2018-07-15',
#     'currentMatchday': 3,
#     'winner': {'id': 773,
#      'name': 'France',
#      'shortName': 'France',
#      'tla': 'FRA',
#      'crestUrl': 'https://upload.wikimedia.org/wikipedia/en/c/c3/Flag_of_France.svg'}},
#    'numberOfAvailableSeasons': 2,
#    'lastUpdated': '2018-08-23T12:16:17Z'}]}
